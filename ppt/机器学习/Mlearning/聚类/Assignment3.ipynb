# %% [markdown]
# # 第三题：使用sklearn的AgglomerativeClustering完成层次聚类
#
# 实验内容：
# 1. 使用sklearn的AgglomerativeClustering完成两个数据集的层次聚类
# 2. 计算外部指标FMI和NMI
# 3. 对6种形式的聚类效果可视化
#
# **注意：在运行本notebook前需要讲sklearn更新至0.20及以上版本**

# %% [markdown]
# # 1. 导入模块

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. 生成数据集

# %%
from sklearn import datasets
X1, y1 = datasets.make_circles(n_samples = 1500, factor = 0.5, noise = 0.05, random_state = 32)
X2, y2 = datasets.make_moons(n_samples = 1500, noise = 0.05, random_state = 32)

# %%
colors = np.array(['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999', '#e41a1c', '#dede00'])

# %%
plt.title('dataset1')
plt.scatter(X1[:, 0], X1[:, 1], s = 10, c = colors[y1])

# %%
plt.title('dataset2')
plt.scatter(X2[:, 0], X2[:, 1], s = 10, c = colors[y2])

# %% [markdown]
# # 3. 导入模型

# %%
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# # 4. 聚类

# %% [markdown]
# 层次聚类的`linkage`参数表示我们要用哪种距离（最小、最大、平均）进行聚类。这里我们选择`single`，表示最小距离。`complete`表示最大距离，`average`表示平均距离。
#
# **注意：single参数是在sklearn 0.20版本才加入的！**

# %%
model = AgglomerativeClustering(n_clusters = 2, linkage="single")
model.fit(X1)
# Out:
# AgglomerativeClustering(linkage='single')

# %% [markdown]
# 对于层次聚类算法，我们可以使用`labels_`属性获得聚类结果

# %% [markdown]
# # 5. 聚类效果可视化

# %%
pred = model.labels_
plt.title('dataset1')
plt.scatter(X1[:, 0], X1[:, 1], s = 10, color = colors[pred])

# %% [markdown]
# # Test
#
# 请你完成"single"，"complete"和"average"三种距离在两个数据集上的聚类任务，并绘制出聚类结果，计算6种情况的FMI和NMI
#
# ###### 双击此处填写
#
# ## 1. 数据集1
#
# 距离度量方式|FMI|NMI
# -|-|-
# single|1.0|1.0
# complete|0.5092291475803045|0.003348941916219493
# average|0.5039593145853657|0.003123748100310852
#
# ## 2. 数据集2
#
# 距离度量方式|FMI|NMI
# -|-|-
# single|1.0|1.0
# complete|0.675584452162688|0.2768473539399129
# average|0.7660505593160595|0.5261058619486623

# %%
# YOUR CODE HERE
from sklearn.metrics import normalized_mutual_info_score
from sklearn.metrics import fowlkes_mallows_score

model1 = AgglomerativeClustering(n_clusters = 2, linkage="single")
model1.fit(X1)
pred = model1.labels_
plt.title('dataset1')
plt.scatter(X1[:, 0], X1[:, 1], s = 10, color = colors[pred])

print(fowlkes_mallows_score(y1, model1.labels_))
print(normalized_mutual_info_score(y1, model1.labels_))
# Out:
# 1.0
# 1.0

# %%
model1 = AgglomerativeClustering(n_clusters = 2, linkage="complete")
model1.fit(X1)
pred = model1.labels_
plt.title('dataset1')
plt.scatter(X1[:, 0], X1[:, 1], s = 10, color = colors[pred])

print(fowlkes_mallows_score(y1, model1.labels_))
print(normalized_mutual_info_score(y1, model1.labels_))
# Out:
# 0.5092291475803045
# 0.003348941916219493

# %%
model1 = AgglomerativeClustering(n_clusters = 2, linkage="average")
model1.fit(X1)
pred = model1.labels_
plt.title('dataset1')
plt.scatter(X1[:, 0], X1[:, 1], s = 10, color = colors[pred])

print(fowlkes_mallows_score(y1, model1.labels_))
print(normalized_mutual_info_score(y1, model1.labels_))
# Out:
# 0.5039593145853657
# 0.003123748100310852

# %% [markdown]
# ## dataset2

# %%
model2 = AgglomerativeClustering(n_clusters = 2, linkage="single")
model2.fit(X2)
pred = model2.labels_
plt.title('dataset2')
plt.scatter(X2[:, 0], X2[:, 1], s = 10, color = colors[pred])

print(fowlkes_mallows_score(y2, model2.labels_))
print(normalized_mutual_info_score(y2, model2.labels_))
# Out:
# 1.0
# 1.0

# %%
model2 = AgglomerativeClustering(n_clusters = 2, linkage="complete")
model2.fit(X2)
pred = model2.labels_
plt.title('dataset2')
plt.scatter(X2[:, 0], X2[:, 1], s = 10, color = colors[pred])

print(fowlkes_mallows_score(y2, model2.labels_))
print(normalized_mutual_info_score(y2, model2.labels_))
# Out:
# 0.675584452162688
# 0.2768473539399129

# %%
model2 = AgglomerativeClustering(n_clusters = 2, linkage="average")
model2.fit(X2)
pred = model2.labels_
plt.title('dataset2')
plt.scatter(X2[:, 0], X2[:, 1], s = 10, color = colors[pred])

print(fowlkes_mallows_score(y2, model2.labels_))
print(normalized_mutual_info_score(y2, model2.labels_))
# Out:
# 0.7660505593160595
# 0.5261058619486623
